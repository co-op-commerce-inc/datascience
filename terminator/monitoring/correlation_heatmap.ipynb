# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from scipy.stats import beta
import plotly.express as px
from datetime import datetime

import warnings
# Filter out all warnings
warnings.filterwarnings('ignore', category=Warning)

# %%
df = pd.read_csv('/Users/peter/datascience/terminator/monitoring/data/input/longitudinal.csv')
#Remove comma from all columns
df = df.replace(',','', regex=True)
#Convert all columns except date to numeric
df.iloc[:, 1:] = df.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
#convert date to datetime
df['date'] = pd.to_datetime(df['date'])
df.sample(5)
# Out:
#           date  Orders   Events Conversions Widget Loads Page Loads Sessions
# 11  2023-10-23   99751  2009629         491       100755     125454   172249
# 68  2023-12-19  134938  3424338         387       179327     218280   273917
# 26  2023-11-07  123056  2581926         724       132703     166363   218958
# 103 2024-01-23  109499  2281872         385       121257     153047   193640
# 154 2024-03-14  131323  2563084         807       152778     180231   202906

# %%
#Create a correlation heatmap of all the metrics except date
corr = df.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >
