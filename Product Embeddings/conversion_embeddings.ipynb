# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import ast
from scipy.stats import beta
from snowflake import connector
import pandas as pd

from dotenv import load_dotenv
from tabulate import tabulate
import openai

# %% [markdown]
# ## Ingest and Process Data

# %%
df = pd.read_csv('data/products.csv')
#change all columns to lowercase
df.columns = map(str.lower, df.columns)
df.sample(5)
# Out:
#           event_brand_name  remote_order_id  \
# 20827                 Lalo    4138977984576
# 10350                 ILIA    5434766655657
# 19660   Monica & Andy Inc.    6002202214462
# 31621  August Uncommon Tea    5710096761127
# 24928         Laura Geller    5670798917693
#
#                                  session_id    pub_date  \
# 20827  8f92d7a3-4221-4875-9be2-1de5ce3a0fb4  2024-03-13
# 10350  46afedc6-f491-4e80-855e-f32e1f0d1689  2024-03-04
# 19660  87ae212d-6f26-4643-8c74-50428400ddd0  2024-01-05
# 31621  d9c0660f-4ad9-4ffd-b3bc-e1cdb46b7fb0  2024-01-15
# 24928  ac001e52-c866-418e-95fb-af7ffbc9c50f  2024-02-15
#
#                                         event_line_items  \
# 20827  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 10350  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 19660  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 31621  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 24928  [\n  {\n    "discount_amount": "0.00",\n    "p...
#
#                                    event_id   conv_date  conv_order_id  \
# 20827  4f0dbf58-bfa0-45df-ac48-0185c378c0bb  2024-03-16  5202958712971
# 10350  55c3862d-64d7-407c-a2ad-d1b67cea35e0  2024-03-09  5384084553830
# 19660  f5282dca-9bc7-4379-ba92-043768e4f479  2024-01-12  5390977335490
# 31621  ede354ac-3c83-4610-9db1-0bb9f0698a81  2024-01-16  5366134014123
# 24928  82965b9e-fab7-4f43-bbc2-40f1492a9180  2024-02-25  5639432208451
#
#            conv_brand_name                                    conv_line_items
# 20827                Nanit  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 10350       Sol de Janeiro  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 19660  Tubby Todd Bath Co.  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 31621         Pretzels.com  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 24928        Love in Faith  [\n  {\n    "discount_amount": "0.00",\n    "p...

# %%
def parse_products_sales(s):
    # Initialize empty lists to hold products and sales
    product_names = []
    sales = []
    
    # Check if the input is a string. If not, return empty lists.
    if not isinstance(s, str):
        return product_names, sales
    
    try:
        # Convert the string representation of the list of dicts to an actual list of dicts
        products_list = ast.literal_eval(s.replace('\n', '').replace('null', 'None'))
        
        # Extract product names and calculate sales
        product_names = [product['product_name'] for product in products_list]
        sales = [float(product['quantity']) * (float(product['price']) - float(product['discount_amount'])) for product in products_list]
        
        return product_names, sales
    except (ValueError, SyntaxError) as e:
        # If there's an error in converting, print the error and return empty lists
        print(f"Error parsing row: {e}")
        return product_names, sales

# %%
df[['pub_products', 'pub_sales']] = df.apply(lambda row: parse_products_sales(row['event_line_items']), axis=1, result_type='expand')
df[['conv_products', 'conv_sales']] = df.apply(lambda row: parse_products_sales(row['conv_line_items']), axis=1, result_type='expand')
df.sample(5)
# Out:
#       event_brand_name  remote_order_id                            session_id  \
# 9066      Bask Suncare    5538448736498  3e3a16bc-1257-4cc4-8b6b-9fd069c51561
# 5742              Lalo    4127745081408  27c5abac-d8e9-4968-a905-abf526bab5ea
# 21427     Laura Geller    5583386345533  939e615a-0a0c-4f99-a94b-e44b46844477
# 16815       Caden Lane    5227258806332  73a0cd97-1689-4663-8fc3-1a8bba16927a
# 12365    Doggy Do Good    5641372369212  54d18f36-3a25-48fe-83b9-127d104f1087
#
#          pub_date                                   event_line_items  \
# 9066   2024-03-08  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 5742   2024-02-09  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 21427  2024-01-05                                                NaN
# 16815  2024-03-02  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 12365  2024-01-24  [\n  {\n    "discount_amount": "0.00",\n    "p...
#
#                                    event_id   conv_date  conv_order_id  \
# 9066   274ed6a9-db88-41ff-bf1c-2f66353b3163  2024-03-14  5287299088561
# 5742   250f5c50-5b76-4077-b1d3-fce4e25a6d4b  2024-03-17  5291716673713
# 21427  44f3b1e5-3415-454b-8d99-860720841b39  2024-01-05  5282994815078
# 16815  5e281451-89e4-40aa-a61a-ad62cdfe61fc  2024-03-02  5451605573826
# 12365  705523cc-9f2d-4f74-9c52-dfd987592b7a  2024-02-07  4860557197464
#
#       conv_brand_name                                    conv_line_items  \
# 9066            HATCH  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 5742            HATCH  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 21427  Sol de Janeiro  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 16815         Coterie  [\n  {\n    "discount_amount": "0.00",\n    "p...
# 12365        For Days  [\n  {\n    "discount_amount": "0.00",\n    "p...
#
#                                             pub_products            pub_sales  \
# 9066   [Route Package Protection - $3.55, SPF 50 Six-...        [3.55, 115.2]
# 5742   [The Play Table - Natural, Play Legs - Blueber...  [170.0, 40.0, 40.0]
# 21427                                                 []                   []
# 16815  [Henlee's Hydrangea Newborn Baby Knot Gown & H...         [36.0, 48.0]
# 12365                                      [Refill Pack]              [35.99]
#
#                                            conv_products  \
# 9066   [The Essential Nursing And Pumping Bra - Black...
# 5742   [The Boyfriend Maternity Jean - Destroyed Ligh...
# 21427  [Delícia Drench™ Body Butter Sample, Brazilian...
# 16815                                 [The Newborn Gift]
# 12365  [Laundry Detergent Sheets - Unscented, Take Ba...
#
#                                      conv_sales
# 9066                                     [78.0]
# 5742   [198.0, 198.0, 128.0, 218.0, 88.0, 98.0]
# 21427                    [0.0, 22.0, 0.0, 38.0]
# 16815                                   [125.0]
# 12365                             [19.99, 20.0]

# %% [markdown]
# ## Find Top Product Combos

# %%
def analyze_conversion_products_sales(df):
    expanded_data = []
    for idx, row in df.iterrows():
        for product, sale in zip(row['pub_products'], row['pub_sales']):
            expanded_data.append({
                'publisher_brand_name': row['event_brand_name'],
                'publisher_product': product,
                'sale': sale,
                'conv_brand_name': row['conv_brand_name'],
                'conv_products': row['conv_products'],
                'conv_sales': row['conv_sales']
            })

    expanded_df = pd.DataFrame(expanded_data)
    
    # Aggregate sales by publisher product and sort
    pub_products_sales = expanded_df.groupby(['publisher_brand_name', 'publisher_product'])['sale'].sum().reset_index()
    pub_products_sales_sorted = pub_products_sales.sort_values(by='sale', ascending=False)
    
    # For each publisher product, identify the top 5 conversion products by sales
    top_conversion_products = {}
    for _, row in pub_products_sales_sorted.iterrows():
        publisher_product = row['publisher_product']
        relevant_rows = expanded_df[expanded_df['publisher_product'] == publisher_product]
        conversion_sales = {}
        for _, conv_row in relevant_rows.iterrows():
            for conv_product, conv_sale, conv_brand_name in zip(conv_row['conv_products'], conv_row['conv_sales'], [conv_row['conv_brand_name']] * len(conv_row['conv_products'])):
                conversion_sales[f"{conv_brand_name} - {conv_product}"] = conversion_sales.get(f"{conv_brand_name} - {conv_product}", 0) + conv_sale
        
        # Sort conversion products by sales and take the top 5
        sorted_conv_sales = sorted(conversion_sales.items(), key=lambda x: x[1], reverse=True)[:5]
        top_conversion_products[publisher_product] = sorted_conv_sales
    
    # Prepare the final DataFrame
    final_data = []
    for pub_product, conv_products in top_conversion_products.items():
        row = {
            'publisher_brand_name': expanded_df[expanded_df['publisher_product'] == pub_product]['publisher_brand_name'].iloc[0],
            'publisher_product': pub_product
        }
        for i, (conv_product_sale, sale) in enumerate(conv_products, 1):
            conv_product, conv_brand_name = conv_product_sale.split(' - ', 1)
            row[f'top_{i}_conv_brand_name'] = conv_product
            row[f'top_{i}_conv_product'] = conv_brand_name
            row[f'top_{i}_conv_sale'] = sale
        final_data.append(row)

    return pd.DataFrame(final_data)

# %%
top_product_sales = analyze_conversion_products_sales(df)
top_product_sales.head()
# Out:
#   publisher_brand_name                            publisher_product  \
# 0          Newton Baby             Crib Mattress - Standard / White
# 1          Newton Baby  Waterproof Crib Mattress - Standard / White
# 2                Nanit       Nanit Pro Camera - Floor Stand / White
# 3                 Nood               The Flasher™ 2.0 - Matte Black
# 4         Willow Pumps  Willow Go™ Wearable Breast Pump - 21 & 24mm
#
#   top_1_conv_brand_name                                 top_1_conv_product  \
# 0                 Nanit              Nanit Pro Camera - Wall Mount / White
# 1                 Nanit             Nanit Pro Camera - Floor Stand / White
# 2           Newton Baby        Waterproof Crib Mattress - Standard / White
# 3                  Koio   Mello in Summit Regenerative - 10 (US) / 43 (EU)
# 4                 Nanit  The Best-Selling Camera Bundle - Floor Stand /...
#
#    top_1_conv_sale top_2_conv_brand_name  \
# 0          1495.00                 Nanit
# 1           798.00                 Nanit
# 2          1049.97           Newton Baby
# 3           395.00        Sunday Citizen
# 4           359.00           Newton Baby
#
#                                   top_2_conv_product  top_2_conv_sale  \
# 0             Nanit Pro Camera - Floor Stand / White           399.00
# 1   Nanit Pro Camera Multi-Pack - Twin / Floor Stand           679.00
# 2                   Crib Mattress - Standard / White           899.97
# 3  Premium Bamboo Bubble Comforter - Taupe / King...           290.00
# 4        Waterproof Crib Mattress - Standard / White           349.99
#
#   top_3_conv_brand_name                         top_3_conv_product  \
# 0                 Nanit  Best Sellers Bundle - Floor Stand / Green
# 1                 Nanit             Nanit Pro Camera - Floor Stand
# 2                  Lalo                        The Chair - Coconut
# 3        Sol de Janeiro     Biggie Biggie Beija Flor™ Elasti-Cream
# 4           Dagne Dover   Indi Diaper Backpack in Dark Moss, Large
#
#    top_3_conv_sale top_4_conv_brand_name  \
# 0           383.00                 Nanit
# 1           399.00                 Nanit
# 2           470.00           Newton Baby
# 3           255.00            Ursa Major
# 4           182.75                 HATCH
#
#                                   top_4_conv_product  top_4_conv_sale  \
# 0  The Best-Selling Camera Bundle - Wall Mount / ...           303.00
# 1  The Best-Selling Camera Bundle - Floor Stand /...           383.00
# 2                Travel Crib & Play Yard - Play Yard           449.98
# 3            Golden Hour Recovery Cream - 1.57 FL OZ           156.00
# 4            The Mackenzie Sweater Dress - Black / 1           147.60
#
#   top_5_conv_brand_name                                top_5_conv_product  \
# 0           Dagne Dover          Indi Diaper Backpack in Dark Moss, Large
# 1                 Nanit   First Year Bundle - Floor Stand / Pink Sunburst
# 2           Newton Baby        Waterproof Crib Mattress - Standard / Grey
# 3              Vegamour  GRO+ Advanced Hair Serum (3 Pack) - Subscription
# 4           M.M.LaFleur     Brodie Top - Airy Stripe Knit :: Meringue - M
#
#    top_5_conv_sale
# 0           215.00
# 1           383.00
# 2           349.99
# 3           149.00
# 4           135.00

# %%
top_product_sales.loc[top_product_sales['publisher_brand_name'] == 'Caraway'].head(25)
# Out:
#      publisher_brand_name                     publisher_product  \
# 52                Caraway                  Cookware Set - Cream
# 140               Caraway              Food Storage Set - Cream
# 161               Caraway          Cutting Board Set - FSC Wood
# 233               Caraway                   Cookware Set - Gray
# 347               Caraway                     Minis Duo - Cream
# 473               Caraway             Half Bakeware Set - Cream
# 666               Caraway                   Bakeware Set - Navy
# 667               Caraway                   Bakeware Set - Gray
# 669               Caraway                   Bakeware Set - Sage
# 670               Caraway                   Cookware Set - Sage
# 671               Caraway                   Cookware Set - Navy
# 678               Caraway          Whistling Tea Kettle - Cream
# 728               Caraway                    Fry Pan Duo - Navy
# 736               Caraway               Food Storage Set - Gray
# 804               Caraway        Cookware Set - Stainless Steel
# 847               Caraway                       Fry Pan - Cream
# 945               Caraway                      Minis Duo - Gray
# 973               Caraway                  Bakeware Set - White
# 975               Caraway                  Cookware Set - Black
# 976               Caraway                  Cookware Set - White
# 978               Caraway                  Bakeware Set - Black
# 1014              Caraway  Kitchen Gadget Set - Stainless Steel
# 1049              Caraway                     Sauce Pan - Cream
# 1109              Caraway                    Fry Pan Duo - Sage
# 1302              Caraway          Double Burner Griddle - Navy
#
#       top_1_conv_brand_name  \
# 52                   Branch
# 140             Dagne Dover
# 161                 vitruvi
# 233            True Classic
# 347                  Branch
# 473                    Lalo
# 666                 vitruvi
# 1302            24.99                   NaN
#
#                                      top_4_conv_product  top_4_conv_sale  \
# 52                Giant Coloring Sheets - Food / 3 Pack           130.00
# 140               Giant Coloring Sheets - Food / 3 Pack           130.00
# 161   Kids Happy Hair Duo - 2-piece set + Free hair ...           108.00
# 233    Berry Happy Convertible Zip Romper - 6-12 months            36.00
# 347               Giant Coloring Sheets - Food / 3 Pack           130.00
# 473   Millie's Floral Personalized Newborn Baby Knot...            56.00
# 666                                      After Midnight            28.00
# 667                                                 NaN              NaN
# 669                          Package Protection - $1.95             1.95
# 670                          Package Protection - $1.95             1.95
# 671                                                Dusk             0.00
# 678                                      After Midnight            28.00
# 728   Snuggle Bunny Two Piece Pajama Set | Pink - 18...            36.00
# 736   Baked Balance-n-Brighten Color Correcting Foun...            21.60
# 804                                                 NaN              NaN
# 847                     Landon Carryall in Onyx, Medium           157.25
# 945   Weslie's Wildflower Convertible Zip Romper - 6...            36.00
# 973                                                 NaN              NaN
# 975                                                 NaN              NaN
# 976                                                 NaN              NaN
# 978                                                 NaN              NaN
# 1014                                           Holly 4N            48.00
# 1049                               Plumping Mask (1 oz)            40.00
# 1109                                       Flax Swaddle            28.00
# 1302                                                NaN              NaN
#
#      top_5_conv_brand_name                                 top_5_conv_product  \
# 52                    Lalo            Giant Coloring Sheets - Safari / 3 Pack
# 140                   Lalo            Giant Coloring Sheets - Safari / 3 Pack
# 161               Evereden                  Kids Happy Hair Day - 3-piece set
# 233             Caden Lane  Weslie's Wildflower Convertible Zip Romper - 6...
# 347                   Lalo            Giant Coloring Sheets - Safari / 3 Pack
# 473                   Lalo                        Utensils - Oatmeal / 4 Pack
# 666                   ILIA               Free Mini Fullest Volumizing Mascara
# 667                    NaN                                                NaN
# 669                    NaN                                                NaN
# 670                    NaN                                                NaN
# 671                vitruvi                                               Rest
# 678                   ILIA                                             Tahiti
# 728             MantraBand  God Is Within Her, She Will Not Fall - Silver ...
# 736             Caden Lane                         Glacier Silicone Snack Cup
# 804                    NaN                                                NaN
# 847            Dagne Dover                 Hunter Toiletry Bag in Onyx, Large
# 945             Caden Lane  Vera's Vintage Floral Convertible Zip Romper -...
# 973                    NaN                                                NaN
# 975                    NaN                                                NaN
# 976                    NaN                                                NaN
# 978                    NaN                                                NaN
# 1014                  ILIA                                   Complexion Brush
# 1049         Primally Pure                             Clarifying Mask (1 oz)
# 1109            Solly Baby                                      Swell Swaddle
# 1302                   NaN                                                NaN
#
#       top_5_conv_sale
# 52             130.00
# 140            130.00
# 161             79.00
# 233             36.00
# 347            130.00
# 473             42.50
# 666              0.00
# 667               NaN
# 669               NaN
# 670               NaN
# 671              0.00
# 678             26.00
# 728             25.00
# 736             14.00
# 804               NaN
# 847             55.25
# 945             36.00
# 973               NaN
# 975               NaN
# 976               NaN
# 978               NaN
# 1014            34.00
# 1049            40.00
# 1109            28.00
# 1302              NaN

# %%
def analyze_conversion_products_frequency(df):
    expanded_data = []
    # Iterate over each row in the DataFrame
    for idx, row in df.iterrows():
        for product, sale in zip(row['pub_products'], row['pub_sales']):
            # Extract the corresponding conversion brand names and products
            conv_brands_products = list(zip(row['conv_brand_name'], row['conv_products']))
            # Collect conversion data for this publisher product
            conv_data = []
            for conv_brand, conv_product in conv_brands_products:
                conv_data.append({'conv_brand': conv_brand, 'conv_product': conv_product})

            # Add data to the expanded list
            expanded_data.append({
                'publisher_brand_name': row['event_brand_name'],
                'publisher_product': product,
                'sale': sale,
                'conv_data': conv_data
            })
    
    expanded_df = pd.DataFrame(expanded_data)
    
    # Count frequency of each publisher product
    pub_product_counts = expanded_df.groupby(['publisher_brand_name', 'publisher_product']).size().reset_index(name='frequency')
    pub_product_counts_sorted = pub_product_counts.sort_values(by='frequency', ascending=False)
    
    # For each publisher product, count frequency of each associated conversion product
    top_conversion_products = {}
    for _, row in pub_product_counts_sorted.iterrows():
        publisher_product = row['publisher_product']
        relevant_rows = expanded_df[expanded_df['publisher_product'] == publisher_product]
        conversion_product_counts = {}
        for _, conv_row in relevant_rows.iterrows():
            for conv_product, conv_brand_name in zip(conv_row['conv_products']), conv_row['conv_brand_name']:
                key = f"{conv_brand_name} - {conv_product}"
                conversion_product_counts[key] = conversion_product_counts.get(key, 0) + 1
        
        # Sort conversion products by their frequency and take the top 5
        sorted_conv_product_counts = sorted(conversion_product_counts.items(), key=lambda x: x[1], reverse=True)[:5]
        top_conversion_products[publisher_product] = sorted_conv_product_counts
    
    # Prepare the final DataFrame
    final_data = []
    for pub_product, conv_products in top_conversion_products.items():
        row = {
            'publisher_brand_name': expanded_df[expanded_df['publisher_product'] == pub_product]['publisher_brand_name'].iloc[0],
            'publisher_product': pub_product
        }
        for i, (conv_product_count, count) in enumerate(conv_products, 1):
            conv_brand_name, conv_product = conv_product_count.split(' - ', 1)
            row[f'top_{i}_conv_brand_name'] = conv_brand_name
            row[f'top_{i}_conv_product'] = conv_product
            row[f'top_{i}_conv_frequency'] = count
        final_data.append(row)

    return pd.DataFrame(final_data)

# %%
analyze_conversion_products_frequency(df.head(50))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'conv_products'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 analyze_conversion_products_frequency(df.head(50))
#
# Cell In[46], line 34, in analyze_conversion_products_frequency(df)
#      32 conversion_product_counts = {}
#      33 for _, conv_row in relevant_rows.iterrows():
# ---> 34     for conv_product, conv_brand_name in zip(conv_row['conv_products']), conv_row['conv_brand_name']:
#      35         key = f"{conv_brand_name} - {conv_product}"
#      36         conversion_product_counts[key] = conversion_product_counts.get(key, 0) + 1
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:1112, in Series.__getitem__(self, key)
#    1109     return self._values[key]
#    1111 elif key_is_scalar:
# -> 1112     return self._get_value(key)
#    1114 # Convert generator to list before going through hashable part
#    1115 # (We will iterate through the generator there to check for slices)
#    1116 if is_iterator(key):
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:1228, in Series._get_value(self, label, takeable)
#    1225     return self._values[label]
#    1227 # Similar to Index.get_value, but we do not fall back to positional
# -> 1228 loc = self.index.get_loc(label)
#    1230 if is_integer(loc):
#    1231     return self._values[loc]
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'conv_products'

# %%
### what are users actually buying next (from another publisher)
